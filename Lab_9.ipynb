# %% [markdown]
# <a href="https://colab.research.google.com/github/anshikasoni0107/Algorithm-lab/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):
    distances = {}
    visited = []
    parent = {}

    for node in graph:
        distances[node] = float('inf')
        parent[node] = None

    distances[start] = 0

    while len(visited) < len(graph):
        min_node = None
        min_distance = float('inf')
        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        if min_node is None:
            break

        visited.append(min_node)
        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                parent[neighbor] = min_node

    return distances, parent

def print_paths(distances, parent, start):
    print("\nShortest paths from source:", start)

    for node in distances:
        path = []
        current = node

        while current is not None:
            path.append(current)
            current = parent[current]

        path.reverse()

        print(f"To {node}: Path = {' -> '.join(path)}, Distance = {distances[node]}")

graph = {}

n = int(input("Enter number of nodes: "))

for _ in range(n):
    node = input("\nEnter node name: ")
    graph[node] = {}

    neighbors = int(input(f"Enter number of neighbors for {node}: "))

    for _ in range(neighbors):
        neighbor = input("Enter neighbor: ")
        weight = int(input(f"Enter weight to {neighbor}: "))
        graph[node][neighbor] = weight

while True:
    start = input("\nEnter source node (or 'exit' to stop): ")

    if start.lower() == 'exit':
        break

    if start not in graph:
        print("Invalid node! Try again.")
        continue

    distances, parent = dijkstra(graph, start)
    print_paths(distances, parent, start)
# Out:
# Enter number of nodes: 4
#
# Enter node name: A
# Enter number of neighbors for A: 2
# Enter neighbor: B
# Enter weight to B: 2
# Enter neighbor: C
# Enter weight to C: 0
#
# Enter node name: B
# Enter number of neighbors for B: 2
# Enter neighbor: C
# Enter weight to C: 1
# Enter neighbor: D
# Enter weight to D: 3
#
# Enter node name: C
# Enter number of neighbors for C: 1
# Enter neighbor: D
# Enter weight to D: 4
#
# Enter node name: D
# Enter number of neighbors for D: 1
# Enter neighbor: A
# Enter weight to A: 7
#
# Enter source node (or 'exit' to stop): D
#
# Shortest paths from source: D
# To A: Path = D -> A, Distance = 7
# To B: Path = D -> A -> B, Distance = 9
# To C: Path = D -> A -> C, Distance = 7
# To D: Path = D, Distance = 0
#
# Enter source node (or 'exit' to stop): A
#
# Shortest paths from source: A
# To A: Path = A, Distance = 0
# To B: Path = A -> B, Distance = 2
# To C: Path = A -> C, Distance = 0
# To D: Path = A -> C -> D, Distance = 4
#
# Enter source node (or 'exit' to stop): B
#
# Shortest paths from source: B
# To A: Path = B -> D -> A, Distance = 10
# To B: Path = B, Distance = 0
# To C: Path = B -> C, Distance = 1
# To D: Path = B -> D, Distance = 3
#
# Enter source node (or 'exit' to stop): C
#
# Shortest paths from source: C
# To A: Path = C -> D -> A, Distance = 11
# To B: Path = C -> D -> A -> B, Distance = 13
# To C: Path = C, Distance = 0
# To D: Path = C -> D, Distance = 4
#
# Enter source node (or 'exit' to stop): exit

# %%
graph = {
    'A': {'B': 4, 'C': 2},
    'B': {'A': 4, 'C': 5, 'D': 10},
    'C': {'A': 2, 'B': 5, 'D': 3},
    'D': {'B': 10, 'C': 3}
}

distances, parent = dijkstra(graph, 'A')

for node in distances:
    print("Distance from A to", node, "=", distances[node])
print_paths(distances, parent, 'A')
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5
#
# Shortest paths from source: A
# To A: Path = A, Distance = 0
# To B: Path = A -> B, Distance = 4
# To C: Path = A -> C, Distance = 2
# To D: Path = A -> C -> D, Distance = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.
